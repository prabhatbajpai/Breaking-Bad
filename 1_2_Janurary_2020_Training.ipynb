# %% [markdown]
# <a href="https://colab.research.google.com/github/prabhatbajpai/Breaking-Bad/blob/main/1_2_Janurary_2020_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import glob as glob

# %%
import warnings 
warnings.filterwarnings(action= 'ignore')

# %%
df=pd.read_csv('./gdrive/My Drive/Deanonymization/WE_BC/WE_BC_January/WE_BC_Jan.csv')

# %%
df=df.drop('hash',axis=1)
df=df.drop('time',axis=1)
df=df.drop('date',axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10209236 entries, 0 to 10209235
# Data columns (total 24 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   balance           float64
#  1   label             object
#  2   rec/sent          object
#  3   amount            float64
#  4   block_id          int64
#  5   size              int64
#  6   weight            int64
#  7   version           int64
#  8   lock_time         int64
#  9   is_coinbase       int64
#  10  has_witness       int64
#  11  input_count       int64
#  12  output_count      int64
#  13  input_total       int64
#  14  input_total_usd   float64
#  15  output_total      int64
#  16  output_total_usd  float64
#  17  fee               int64
#  18  fee_usd           float64
#  19  fee_per_kb        float64
#  20  fee_per_kb_usd    float64
#  21  fee_per_kwu       float64
#  22  fee_per_kwu_usd   float64
#  23  cdd_total         float64
# dtypes: float64(10), int64(12), object(2)
# memory usage: 1.8+ GB

# %%
df["label"].replace({"Mining_pools":"Pool"}, inplace=True)

# %%
df['label'].value_counts()
# Out:
# Exchange    168925
# Pool         27838
# Services      4663
# Gambling       610
# Name: label, dtype: int64

# %%
pf2=pd.DataFrame({'label':[168925,27838,4663,610]},
                index=['Exchange','Pool','Services' ,'Gambling'])
plt=pf2.plot.pie(y='label',autopct='%1.1f%%',figsize=(5,5))

# %%
df=df.dropna()

# %%
df.describe()
# Out:
#             rec/sent         amount  ...  fee_per_kwu_usd     cdd_total
# count  202036.000000  202036.000000  ...    202036.000000  2.020360e+05
# mean        0.366910       0.307236  ...         9.252410  6.620889e+01
# std         0.481963       9.004915  ...         5.905838  4.856492e+03
# min         0.000000       0.000005  ...         0.000000 -2.405169e-04
# 25%         0.000000       0.001856  ...         5.777700  3.050118e-02
# 50%         0.000000       0.010041  ...         9.668100  3.835764e-01
# 75%         1.000000       0.049500  ...        12.013300  4.923965e+00
# max         1.000000    2000.000000  ...       258.553900  1.444129e+06
#
# [8 rows x 22 columns]

# %%
# def label_coder():
#   for i in df['label']:
#     if i=='Exchange':
#       i=0
#     elif i=='Services':
#       i=1
#     elif i=='Pool':
#       i=2
#     else: i=3
# label_coder()
df["label"].replace({"Exchange": 0, "Services": 1,"Pool":2,"Gambling":3}, inplace=True)

# %%
from sklearn import preprocessing
def peenc(df):
  label_encoder=preprocessing.LabelEncoder()
  #df['label']=label_encoder.fit_transform(df['label'])
  df['rec/sent']=label_encoder.fit_transform(df['rec/sent'])
peenc(df)

# %%
df['label'].value_counts()
# Out:
# 0    168925
# 2     27838
# 1      4663
# 3       610
# Name: label, dtype: int64

# %%
df=df.drop('balance',axis=1)

# %%
def f1():
  X=df.drop('label',axis=1)
  y=df['label']
  #print(y.value_counts())
  return X,y
X,y=f1()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import SMOTE
def f2():
  X,y=f1()
  X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25)
  norm = MinMaxScaler().fit(X_train)
  X_train = norm.transform(X_train)
  X_test = norm.transform(X_test)
  sm = SMOTE(random_state = 2)
  X_train_res, y_train_res = sm.fit_sample(X_train, y_train.ravel())
  X_test_res,y_test_res=sm.fit_sample(X_test,y_test.ravel())
  return X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res
X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res=f2()
def f3():
  return X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res;

# %%
X_test_res.shape
# Out:
# (168608, 22)

# %%
# visual libraries
from matplotlib import pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D 
plt.style.use('ggplot')

# %%
# visual libraries
from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D 
plt.style.use('ggplot')
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef,classification_report,roc_curve
from sklearn.externals import joblib
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


anomalous_features = df.iloc[:,2:25].columns

plt.figure(figsize=(12,24*4))
gs = gridspec.GridSpec(24, 1)
for i, cn in enumerate(df[anomalous_features]):
    ax = plt.subplot(gs[i])
    sns.distplot(df[cn][df.label == 1], bins=50)
    sns.distplot(df[cn][df.label == 0], bins=50)
    ax.set_xlabel('')
    ax.set_title('histogram of feature: ' + str(cn))
plt.show()

# %% [markdown]
# **Decision_Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
from sklearn.multiclass import OneVsRestClassifier
def cls1():
  X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res=f3()
  dtc=DecisionTreeClassifier(criterion='entropy',max_depth=6)
  ovr=OneVsRestClassifier(dtc)
  ovr.fit(X_train,y_train)
  return ovr.predict_proba(X_test),y_test
pp,y_test=cls1()
fpr = {}
tpr = {}
thresh ={}
n_class = 4
X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res=f3()
for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, pp[:,i], pos_label=i)
    
# plotting    
plt.plot(fpr[0], tpr[0], linestyle='--',color='red', label='Exchange vs Rest')
plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label='Services vs Rest')
plt.plot(fpr[2], tpr[2], linestyle='--',color='blue', label='Pools vs Rest')
plt.plot(fpr[3], tpr[3], linestyle='--',color='brown', label='Gambling vs Rest')
plt.title('Multiclass ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('Multiclass ROC',dpi=600);

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
def DTC():
  X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res=f2()
  dtc=DecisionTreeClassifier(criterion='entropy',max_depth=6)
  dtc.fit(X_train,y_train)
  dtc_y=dtc.predict(X_test);
  target_names = ['Exchange', 'Services', 'Pools','Gambling']
  print(classification_report(y_test,dtc_y,target_names=target_names))
  dtc_res=DecisionTreeClassifier(criterion='entropy',max_depth=6)
  dtc_res.fit(X_train_res,y_train_res)
  res_y=dtc_res.predict(X_test_res);
  print(classification_report(y_test_res,res_y,target_names=target_names))
  print("CV Accuracy")
  print(dtc.score(X_test,y_test))
  print("CV Accuracy after SMOTE")
  print(dtc_res.score(X_test_res,y_test_res))
DTC()
# Out:
#               precision    recall  f1-score   support
#
#     Exchange       0.97      1.00      0.99     42390
#     Services       0.00      0.00      0.00      1158
#        Pools       1.00      1.00      1.00      6814
#     Gambling       0.97      0.58      0.72       147
#
#     accuracy                           0.98     50509
#    macro avg       0.73      0.64      0.68     50509
# weighted avg       0.95      0.98      0.96     50509
#
#               precision    recall  f1-score   support
#
#     Exchange       0.90      0.81      0.85     42390
#     Services       0.92      0.96      0.94     42390
#        Pools       1.00      1.00      1.00     42390
#     Gambling       0.85      0.90      0.88     42390
#
#     accuracy                           0.92    169560
#    macro avg       0.92      0.92      0.92    169560
# weighted avg       0.92      0.92      0.92    169560
#
# CV Accuracy
# 0.975331129105704
# CV Accuracy after SMOTE
# 0.9180113234253362

# %% [markdown]
# **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.multiclass import OneVsRestClassifier
def cls1():
  X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res=f3()
  dtc=KNeighborsClassifier(n_neighbors=10)
  ovr=OneVsRestClassifier(dtc)
  ovr.fit(X_train,y_train)
  return ovr.predict_proba(X_test),y_test
pp,y_test=cls1()
fpr = {}
tpr = {}
thresh ={}
n_class = 4
X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res=f3()
for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, pp[:,i], pos_label=i)
    
# plotting    
plt.plot(fpr[0], tpr[0], linestyle='--',color='red', label='Exchange vs Rest')
plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label='Services vs Rest')
plt.plot(fpr[2], tpr[2], linestyle='--',color='blue', label='Pools vs Rest')
plt.plot(fpr[3], tpr[3], linestyle='--',color='brown', label='Gambling vs Rest')
plt.title('Multiclass ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('Multiclass ROC',dpi=600);

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
def cls3():
  X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res=f3()
  knn=KNeighborsClassifier(n_neighbors=10)
  knn.fit(X_train,y_train)
  knn_y=knn.predict(X_test);
  target_names = ['Exchange', 'Services', 'Pools','Gambling']
  print(classification_report(y_test,knn_y,target_names=target_names))
  knn_res=KNeighborsClassifier(n_neighbors=10)
  knn_res.fit(X_train_res,y_train_res)
  res_y=knn_res.predict(X_test_res);
  print(classification_report(y_test_res,res_y,target_names=target_names))
  print("CV Accuracy")
  print(knn.score(X_test,y_test))
  print("CV Accuracy after SMOTE")
  print(knn_res.score(X_test_res,y_test_res))
cls3()
# Out:
#               precision    recall  f1-score   support
#
#     Exchange       0.97      0.99      0.98     42152
#     Services       0.24      0.11      0.15      1213
#        Pools       1.00      1.00      1.00      6984
#     Gambling       0.67      0.01      0.02       160
#
#     accuracy                           0.97     50509
#    macro avg       0.72      0.53      0.54     50509
# weighted avg       0.96      0.97      0.96     50509
#
#               precision    recall  f1-score   support
#
#     Exchange       0.73      0.93      0.82     42152
#     Services       0.92      0.94      0.93     42152
#        Pools       1.00      1.00      1.00     42152
#     Gambling       0.94      0.66      0.78     42152
#
#     accuracy                           0.88    168608
#    macro avg       0.90      0.88      0.88    168608
# weighted avg       0.90      0.88      0.88    168608
#
# CV Accuracy
# 0.9671147716248589
# CV Accuracy after SMOTE
# 0.8831905959385082

# %% [markdown]
# **Random_Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.multiclass import OneVsRestClassifier
def cls1():
  X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res=f3()
  rf=RandomForestClassifier(max_depth=5,random_state=0)
  ovr=OneVsRestClassifier(rf)
  ovr.fit(X_train,y_train)
  return ovr.predict_proba(X_test),y_test
pp,y_test=cls1()
fpr = {}
tpr = {}
thresh ={}
n_class = 4
X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res=f3()
for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, pp[:,i], pos_label=i)
    
# plotting    
plt.plot(fpr[0], tpr[0], linestyle='--',color='red', label='Exchange vs Rest')
plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label='Servies vs Rest')
plt.plot(fpr[2], tpr[2], linestyle='--',color='blue', label='Pool vs Rest')
plt.plot(fpr[3], tpr[3], linestyle='--',color='brown', label='Gambling vs Rest')
plt.title('Multiclass ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('Multiclass ROC',dpi=600);

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
def cls4():
  X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res=f3()
  rf=RandomForestClassifier(max_depth=5,random_state=0)
  target_names = ['Exchange', 'Services', 'Pools','Gambling']
  rf.fit(X_train,y_train)
  rf_y=rf.predict(X_test)
  print(classification_report(y_test,rf_y,target_names=target_names))
  rfs=RandomForestClassifier(max_depth=5,random_state=0)
  rfs.fit(X_train_res,y_train_res)
  res_y=rfs.predict(X_test_res)
  print(classification_report(y_test_res,res_y,target_names=target_names))
  print(rf.score(X_test,y_test))
  print(rfs.score(X_test_res,y_test_res))
cls4()
# Out:
#               precision    recall  f1-score   support
#
#     Exchange       0.97      1.00      0.98     42152
#     Services       0.00      0.00      0.00      1213
#        Pools       1.00      1.00      1.00      6984
#     Gambling       0.00      0.00      0.00       160
#
#     accuracy                           0.97     50509
#    macro avg       0.49      0.50      0.50     50509
# weighted avg       0.95      0.97      0.96     50509
#
#               precision    recall  f1-score   support
#
#     Exchange       0.79      0.84      0.82     42152
#     Services       0.92      0.93      0.93     42152
#        Pools       1.00      1.00      1.00     42152
#     Gambling       0.89      0.82      0.85     42152
#
#     accuracy                           0.90    168608
#    macro avg       0.90      0.90      0.90    168608
# weighted avg       0.90      0.90      0.90    168608
#
# 0.9719455938545606
# 0.8985694628961852

# %% [markdown]
# **Adaptive Boosting**

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.multiclass import OneVsRestClassifier
def cls1():
  X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res=f3()
  ab=AdaBoostClassifier(n_estimators=100,random_state=0)
  ovr=OneVsRestClassifier(ab)
  ovr.fit(X_train,y_train)
  return ovr.predict_proba(X_test),y_test
pp,y_test=cls1()
fpr = {}
tpr = {}
thresh ={}
n_class = 4
X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res=f3()
for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, pp[:,i], pos_label=i)
    
# plotting    
plt.plot(fpr[0], tpr[0], linestyle='--',color='red', label='Exchange vs Rest')
plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label='Services vs Rest')
plt.plot(fpr[2], tpr[2], linestyle='--',color='blue', label='Pool vs Rest')
plt.plot(fpr[3], tpr[3], linestyle='--',color='brown', label='Gambling vs Rest')
plt.title('Multiclass ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('Multiclass ROC',dpi=600);

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report
def cls5():
  X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res=f3()
  ab=AdaBoostClassifier(n_estimators=100,random_state=0)
  target_names = ['Exchange', 'Services', 'Pools','Gambling']
  ab.fit(X_train,y_train)
  ab_y=ab.predict(X_test)
  print(classification_report(y_test,ab_y,target_names=target_names))
  abs=AdaBoostClassifier(n_estimators=100,random_state=0)
  abs.fit(X_train_res,y_train_res)
  abs_y=abs.predict(X_test_res)
  print(classification_report(y_test_res,abs_y,target_names=target_names))
  print(ab.score(X_test,y_test))
  print(abs.score(X_test_res,y_test_res))
cls5()
# Out:
#               precision    recall  f1-score   support
#
#     Exchange       0.98      0.46      0.63     42152
#     Services       0.02      0.10      0.03      1213
#        Pools       0.95      0.99      0.97      6984
#     Gambling       0.00      0.45      0.01       160
#
#     accuracy                           0.53     50509
#    macro avg       0.49      0.50      0.41     50509
# weighted avg       0.95      0.53      0.66     50509
#
#               precision    recall  f1-score   support
#
#     Exchange       0.62      0.40      0.48     42152
#     Services       0.74      0.65      0.69     42152
#        Pools       0.97      0.99      0.98     42152
#     Gambling       0.49      0.72      0.58     42152
#
#     accuracy                           0.69    168608
#    macro avg       0.71      0.69      0.69    168608
# weighted avg       0.71      0.69      0.69    168608
#
# 0.5262824447128235
# 0.6902460144239894

# %% [markdown]
# **Gredient_Boosting**

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.multiclass import OneVsRestClassifier
def cls1():
  X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res=f3()
  gcb=gcb=GradientBoostingClassifier(n_estimators=100,max_depth=10,random_state=0)
  ovr=OneVsRestClassifier(gcb)
  ovr.fit(X_train,y_train)
  return ovr.predict_proba(X_test),y_test
pp,y_test=cls1()
fpr = {}
tpr = {}
thresh ={}
n_class = 4
X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res=f3()
for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, pp[:,i], pos_label=i)
    
# plotting    
plt.plot(fpr[0], tpr[0], linestyle='--',color='red', label='Exchange vs Rest')
plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label='Services vs Rest')
plt.plot(fpr[2], tpr[2], linestyle='--',color='blue', label='Pool vs Rest')
plt.plot(fpr[3], tpr[3], linestyle='--',color='brown', label='Gambling vs Rest')
plt.title('Multiclass ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('Multiclass ROC',dpi=1200);

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report
def cls5():
  X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res=f3()
  gcb=GradientBoostingClassifier(n_estimators=100,max_depth=10,random_state=0)
  target_names = ['Exchange', 'Services', 'Pools','Gambling']
  gcb.fit(X_train,y_train)
  gcb_y=gcb.predict(X_test)
  print(classification_report(y_test,gcb_y,target_names=target_names))
  gcbs=GradientBoostingClassifier(n_estimators=100,max_depth=10,random_state=0)
  gcbs.fit(X_train_res,y_train_res)
  gcbs_y=gcbs.predict(X_test_res)
  print(classification_report(y_test_res,gcbs_y,target_names=target_names))
  print(gcb.score(X_test,y_test))
  print(gcbs.score(X_test_res,y_test_res))
cls5()
# Out:
#               precision    recall  f1-score   support
#
#     Exchange       0.97      0.98      0.98     42152
#     Services       0.16      0.15      0.15      1213
#        Pools       1.00      1.00      1.00      6984
#     Gambling       0.77      0.68      0.72       160
#
#     accuracy                           0.96     50509
#    macro avg       0.72      0.70      0.71     50509
# weighted avg       0.96      0.96      0.96     50509
#
#               precision    recall  f1-score   support
#
#     Exchange       0.84      0.97      0.90     42152
#     Services       0.92      0.96      0.94     42152
#        Pools       1.00      1.00      1.00     42152
#     Gambling       0.99      0.81      0.89     42152
#
#     accuracy                           0.93    168608
#    macro avg       0.94      0.93      0.93    168608
# weighted avg       0.94      0.93      0.93    168608
#
# 0.9591755924686689
# 0.9330102960713608

# %% [markdown]
# **ANN**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

model =keras.models.Sequential([
    layers.Dense(units=300,activation='relu',input_shape=[22]),
    layers.Dense(units=512,activation='relu'),
    layers.Dense(units=29,activation ='softmax'),
])

# %%
model.compile(loss='sparse_categorical_crossentropy',
             optimizer="sgd",
             metrics=['accuracy'])

# %%
X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res=f3()
model_history=model.fit(X_train,y_train,validation_data=(X_test,y_test),batch_size=750,epochs=45)
# Out:
# Epoch 1/45
# 203/203 [==============================] - 4s 18ms/step - loss: 2.2096 - accuracy: 0.7808 - val_loss: 0.6356 - val_accuracy: 0.8369
# Epoch 2/45
# 203/203 [==============================] - 3s 16ms/step - loss: 0.5579 - accuracy: 0.8375 - val_loss: 0.4279 - val_accuracy: 0.8369
# Epoch 3/45
# 203/203 [==============================] - 3s 16ms/step - loss: 0.4017 - accuracy: 0.8353 - val_loss: 0.3478 - val_accuracy: 0.8527
# Epoch 4/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.3328 - accuracy: 0.8809 - val_loss: 0.3073 - val_accuracy: 0.9391
# Epoch 5/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.3045 - accuracy: 0.9403 - val_loss: 0.2874 - val_accuracy: 0.9492
# Epoch 6/45
# 203/203 [==============================] - 3s 17ms/step - loss: 0.2832 - accuracy: 0.9491 - val_loss: 0.2761 - val_accuracy: 0.9376
# Epoch 7/45
# 203/203 [==============================] - 3s 17ms/step - loss: 0.2737 - accuracy: 0.9408 - val_loss: 0.2684 - val_accuracy: 0.9297
# Epoch 8/45
# 203/203 [==============================] - 3s 16ms/step - loss: 0.2644 - accuracy: 0.9374 - val_loss: 0.2628 - val_accuracy: 0.9274
# Epoch 9/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.2580 - accuracy: 0.9337 - val_loss: 0.2582 - val_accuracy: 0.9390
# Epoch 10/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.2584 - accuracy: 0.9334 - val_loss: 0.2543 - val_accuracy: 0.9209
# Epoch 11/45
# 203/203 [==============================] - 3s 16ms/step - loss: 0.2510 - accuracy: 0.9297 - val_loss: 0.2502 - val_accuracy: 0.9339
# Epoch 12/45
# 203/203 [==============================] - 3s 16ms/step - loss: 0.2464 - accuracy: 0.9344 - val_loss: 0.2465 - val_accuracy: 0.9320
# Epoch 13/45
# 203/203 [==============================] - 3s 16ms/step - loss: 0.2459 - accuracy: 0.9324 - val_loss: 0.2431 - val_accuracy: 0.9311
# Epoch 14/45
# 203/203 [==============================] - 3s 16ms/step - loss: 0.2428 - accuracy: 0.9334 - val_loss: 0.2399 - val_accuracy: 0.9285
# Epoch 15/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.2361 - accuracy: 0.9329 - val_loss: 0.2365 - val_accuracy: 0.9455
# Epoch 16/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.2327 - accuracy: 0.9368 - val_loss: 0.2333 - val_accuracy: 0.9295
# Epoch 17/45
# 203/203 [==============================] - 3s 16ms/step - loss: 0.2314 - accuracy: 0.9355 - val_loss: 0.2306 - val_accuracy: 0.9274
# Epoch 18/45
# 203/203 [==============================] - 3s 16ms/step - loss: 0.2278 - accuracy: 0.9380 - val_loss: 0.2269 - val_accuracy: 0.9454
# Epoch 19/45
# 203/203 [==============================] - 3s 16ms/step - loss: 0.2238 - accuracy: 0.9429 - val_loss: 0.2235 - val_accuracy: 0.9367
# Epoch 20/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.2223 - accuracy: 0.9438 - val_loss: 0.2202 - val_accuracy: 0.9384
# Epoch 21/45
# 203/203 [==============================] - 3s 16ms/step - loss: 0.2176 - accuracy: 0.9446 - val_loss: 0.2166 - val_accuracy: 0.9465
# Epoch 22/45
# 203/203 [==============================] - 3s 16ms/step - loss: 0.2157 - accuracy: 0.9477 - val_loss: 0.2133 - val_accuracy: 0.9485
# Epoch 23/45
# 203/203 [==============================] - 3s 16ms/step - loss: 0.2084 - accuracy: 0.9499 - val_loss: 0.2100 - val_accuracy: 0.9500
# Epoch 24/45
# 203/203 [==============================] - 3s 16ms/step - loss: 0.2108 - accuracy: 0.9513 - val_loss: 0.2068 - val_accuracy: 0.9529
# Epoch 25/45
# 203/203 [==============================] - 3s 16ms/step - loss: 0.2038 - accuracy: 0.9539 - val_loss: 0.2048 - val_accuracy: 0.9496
# Epoch 26/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.2007 - accuracy: 0.9541 - val_loss: 0.2003 - val_accuracy: 0.9555
# Epoch 27/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1971 - accuracy: 0.9570 - val_loss: 0.1971 - val_accuracy: 0.9568
# Epoch 28/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1972 - accuracy: 0.9580 - val_loss: 0.1941 - val_accuracy: 0.9590
# Epoch 29/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1937 - accuracy: 0.9598 - val_loss: 0.1908 - val_accuracy: 0.9615
# Epoch 30/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1885 - accuracy: 0.9628 - val_loss: 0.1880 - val_accuracy: 0.9629
# Epoch 31/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1860 - accuracy: 0.9630 - val_loss: 0.1845 - val_accuracy: 0.9648
# Epoch 32/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1843 - accuracy: 0.9644 - val_loss: 0.1814 - val_accuracy: 0.9640
# Epoch 33/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1786 - accuracy: 0.9656 - val_loss: 0.1783 - val_accuracy: 0.9654
# Epoch 34/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1773 - accuracy: 0.9651 - val_loss: 0.1753 - val_accuracy: 0.9654
# Epoch 35/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1720 - accuracy: 0.9655 - val_loss: 0.1722 - val_accuracy: 0.9656
# Epoch 36/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1754 - accuracy: 0.9645 - val_loss: 0.1694 - val_accuracy: 0.9654
# Epoch 37/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1634 - accuracy: 0.9671 - val_loss: 0.1664 - val_accuracy: 0.9656
# Epoch 38/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1651 - accuracy: 0.9665 - val_loss: 0.1636 - val_accuracy: 0.9668
# Epoch 39/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1632 - accuracy: 0.9667 - val_loss: 0.1609 - val_accuracy: 0.9671
# Epoch 40/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1580 - accuracy: 0.9675 - val_loss: 0.1590 - val_accuracy: 0.9686
# Epoch 41/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1543 - accuracy: 0.9684 - val_loss: 0.1556 - val_accuracy: 0.9679
# Epoch 42/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1556 - accuracy: 0.9675 - val_loss: 0.1531 - val_accuracy: 0.9682
# Epoch 43/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1509 - accuracy: 0.9688 - val_loss: 0.1506 - val_accuracy: 0.9683
# Epoch 44/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1491 - accuracy: 0.9687 - val_loss: 0.1482 - val_accuracy: 0.9680
# Epoch 45/45
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1466 - accuracy: 0.9689 - val_loss: 0.1459 - val_accuracy: 0.9691

# %%
model_history.history
# Out:
# {'accuracy': [0.8082190155982971,
#   0.8366363644599915,
#   0.8479017019271851,
#   0.9042217135429382,
#   0.9357276558876038,
#   0.9509856104850769,
#   0.9562849998474121,
#   0.9503124952316284,
#   0.9478839039802551,
#   0.9459502100944519,
#   0.9450395107269287,
#   0.944042980670929,
#   0.9446105360984802,
#   0.9436337947845459,
#   0.9448283314704895,
#   0.945151686668396,
#   0.9460161924362183,
#   0.9460294246673584,
#   0.947520911693573,
#   0.948926568031311,
#   0.9508866667747498,
#   0.9520085453987122,
#   0.9538828134536743,
#   0.9552159309387207,
#   0.956779956817627,
#   0.9576709270477295,
#   0.9593933820724487,
#   0.960660457611084,
#   0.9624159336090088,
#   0.9635312557220459,
#   0.9642571806907654,
#   0.9656100869178772,
#   0.9659400582313538,
#   0.9661116600036621,
#   0.966204047203064,
#   0.9662238359451294,
#   0.9664086103439331,
#   0.9665868282318115,
#   0.9673259258270264,
#   0.9678736925125122,
#   0.9683554768562317,
#   0.9685336351394653,
#   0.9686458706855774,
#   0.9689032435417175,
#   0.9690549969673157],
#  'loss': [1.568099021911621,
#   0.5057988166809082,
#   0.380309134721756,
#   0.3264583647251129,
#   0.2970619797706604,
#   0.2807205319404602,
#   0.27081307768821716,
#   0.26382896304130554,
#   0.25823473930358887,
#   0.2536059617996216,
#   0.2495138794183731,
#   0.24567578732967377,
#   0.24199217557907104,
#   0.23845021426677704,
#   0.23495449125766754,
#   0.23150324821472168,
#   0.22811956703662872,
#   0.2247350811958313,
#   0.22137893736362457,
#   0.21802791953086853,
#   0.21469330787658691,
#   0.21137329936027527,
#   0.20803645253181458,
#   0.20469842851161957,
#   0.20139026641845703,
#   0.19804908335208893,
#   0.19473041594028473,
#   0.19144229590892792,
#   0.1881258487701416,
#   0.18483003973960876,
#   0.18158575892448425,
#   0.17833177745342255,
#   0.17509689927101135,
#   0.17190426588058472,
#   0.16874884068965912,
#   0.16565345227718353,
#   0.16258156299591064,
#   0.15955226123332977,
#   0.15666377544403076,
#   0.1537952572107315,
#   0.1509999930858612,
#   0.1482994109392166,
#   0.1456291675567627,
#   0.1430809199810028,
#   0.1406334638595581],
#  'val_accuracy': [0.8345443606376648,
#   0.8345443606376648,
#   0.8744382262229919,
#   0.9207468032836914,
#   0.9402284622192383,
#   0.9544239640235901,
#   0.943990170955658,
#   0.9496129155158997,
#   0.9445841312408447,
#   0.9448810815811157,
#   0.9356748461723328,
#   0.9448810815811157,
#   0.9384466409683228,
#   0.9457126259803772,
#   0.9448810815811157,
#   0.9454948902130127,
#   0.9368627667427063,
#   0.9466233849525452,
#   0.9471777081489563,
#   0.9485834240913391,
#   0.9518897533416748,
#   0.9520283341407776,
#   0.95416659116745,
#   0.9555326700210571,
#   0.9555524587631226,
#   0.9576511383056641,
#   0.9572155475616455,
#   0.9588192105293274,
#   0.9605614542961121,
#   0.9613534212112427,
#   0.9622839689254761,
#   0.96297687292099,
#   0.9635510444641113,
#   0.9639272093772888,
#   0.9636698365211487,
#   0.9639272093772888,
#   0.9638480544090271,
#   0.9664812088012695,
#   0.9643430113792419,
#   0.9667187929153442,
#   0.9666990041732788,
#   0.9648577570915222,
#   0.9676295518875122,
#   0.9675305485725403,
#   0.9678869247436523],
#  'val_loss': [0.6622207760810852,
#   0.4287319481372833,
#   0.3556533455848694,
#   0.31585970520973206,
#   0.2940584421157837,
#   0.2815341651439667,
#   0.27347370982170105,
#   0.26714909076690674,
#   0.26211729645729065,
#   0.2578614056110382,
#   0.2538399398326874,
#   0.2500598132610321,
#   0.2463180124759674,
#   0.24281834065914154,
#   0.23928138613700867,
#   0.23593969643115997,
#   0.23295491933822632,
#   0.22900186479091644,
#   0.22561390697956085,
#   0.22236128151416779,
#   0.21896257996559143,
#   0.21592918038368225,
#   0.21225431561470032,
#   0.20892122387886047,
#   0.20564687252044678,
#   0.20234140753746033,
#   0.19913479685783386,
#   0.19576974213123322,
#   0.1924879550933838,
#   0.18923594057559967,
#   0.1860676109790802,
#   0.18283288180828094,
#   0.17955715954303741,
#   0.17657260596752167,
#   0.17345713078975677,
#   0.17021256685256958,
#   0.16754205524921417,
#   0.16470353305339813,
#   0.1614435762166977,
#   0.1586683988571167,
#   0.15587911009788513,
#   0.1537196934223175,
#   0.15069332718849182,
#   0.1480586975812912,
#   0.14555799961090088]}

# %%
model.evaluate(X_test,y_test)
# Out:
# 1579/1579 [==============================] - 2s 2ms/step - loss: 0.1456 - accuracy: 0.9679
# [0.1455579400062561, 0.9678869247436523]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
pd.DataFrame(model_history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

# %%
model_smo =keras.models.Sequential([
    layers.Dense(units=300,activation='relu',input_shape=[22]),
    layers.Dense(units=512,activation='relu'),
    layers.Dense(units=29,activation ='softmax'),
])

# %%
model_smo.compile(loss='sparse_categorical_crossentropy',
             optimizer="sgd",
             metrics=['accuracy'])

# %%
X_train,X_test,y_train,y_test,X_train_res,y_train_res,X_test_res,y_test_res=f3()
model_history=model_smo.fit(X_train_res,y_train_res,validation_data=(X_test_res,y_test_res),batch_size=750,epochs=45)
# Out:
# Epoch 1/45
# 677/677 [==============================] - 16s 23ms/step - loss: 2.0864 - accuracy: 0.4245 - val_loss: 1.0696 - val_accuracy: 0.6104
# Epoch 2/45
# 677/677 [==============================] - 15s 22ms/step - loss: 1.0126 - accuracy: 0.6307 - val_loss: 0.9041 - val_accuracy: 0.6682
# Epoch 3/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.8724 - accuracy: 0.6679 - val_loss: 0.8188 - val_accuracy: 0.6948
# Epoch 4/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.7947 - accuracy: 0.6937 - val_loss: 0.7505 - val_accuracy: 0.7188
# Epoch 5/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.7305 - accuracy: 0.7225 - val_loss: 0.6939 - val_accuracy: 0.7496
# Epoch 6/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.6771 - accuracy: 0.7485 - val_loss: 0.6375 - val_accuracy: 0.7687
# Epoch 7/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.6249 - accuracy: 0.7828 - val_loss: 0.5857 - val_accuracy: 0.8020
# Epoch 8/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.5771 - accuracy: 0.8090 - val_loss: 0.5422 - val_accuracy: 0.8201
# Epoch 9/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.5359 - accuracy: 0.8184 - val_loss: 0.5100 - val_accuracy: 0.8224
# Epoch 10/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.5066 - accuracy: 0.8220 - val_loss: 0.4860 - val_accuracy: 0.8247
# Epoch 11/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.4844 - accuracy: 0.8255 - val_loss: 0.4687 - val_accuracy: 0.8293
# Epoch 12/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.4686 - accuracy: 0.8263 - val_loss: 0.4554 - val_accuracy: 0.8307
# Epoch 13/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.4554 - accuracy: 0.8272 - val_loss: 0.4464 - val_accuracy: 0.8307
# Epoch 14/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.4452 - accuracy: 0.8291 - val_loss: 0.4393 - val_accuracy: 0.8319
# Epoch 15/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.4382 - accuracy: 0.8283 - val_loss: 0.4328 - val_accuracy: 0.8308
# Epoch 16/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.4337 - accuracy: 0.8289 - val_loss: 0.4283 - val_accuracy: 0.8358
# Epoch 17/45
# 677/677 [==============================] - 15s 23ms/step - loss: 0.4281 - accuracy: 0.8308 - val_loss: 0.4249 - val_accuracy: 0.8338
# Epoch 18/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.4221 - accuracy: 0.8314 - val_loss: 0.4206 - val_accuracy: 0.8352
# Epoch 19/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.4172 - accuracy: 0.8333 - val_loss: 0.4177 - val_accuracy: 0.8370
# Epoch 20/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.4151 - accuracy: 0.8330 - val_loss: 0.4152 - val_accuracy: 0.8380
# Epoch 21/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.4137 - accuracy: 0.8336 - val_loss: 0.4141 - val_accuracy: 0.8334
# Epoch 22/45
# 677/677 [==============================] - 15s 23ms/step - loss: 0.4105 - accuracy: 0.8343 - val_loss: 0.4109 - val_accuracy: 0.8372
# Epoch 23/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.4074 - accuracy: 0.8352 - val_loss: 0.4087 - val_accuracy: 0.8390
# Epoch 24/45
# 677/677 [==============================] - 15s 23ms/step - loss: 0.4035 - accuracy: 0.8363 - val_loss: 0.4072 - val_accuracy: 0.8412
# Epoch 25/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.4032 - accuracy: 0.8357 - val_loss: 0.4058 - val_accuracy: 0.8374
# Epoch 26/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.4008 - accuracy: 0.8372 - val_loss: 0.4045 - val_accuracy: 0.8379
# Epoch 27/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3997 - accuracy: 0.8375 - val_loss: 0.4033 - val_accuracy: 0.8459
# Epoch 28/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3981 - accuracy: 0.8382 - val_loss: 0.4024 - val_accuracy: 0.8460
# Epoch 29/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3952 - accuracy: 0.8392 - val_loss: 0.3996 - val_accuracy: 0.8382
# Epoch 30/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3931 - accuracy: 0.8402 - val_loss: 0.3975 - val_accuracy: 0.8449
# Epoch 31/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3936 - accuracy: 0.8396 - val_loss: 0.3959 - val_accuracy: 0.8466
# Epoch 32/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3915 - accuracy: 0.8418 - val_loss: 0.3979 - val_accuracy: 0.8468
# Epoch 33/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3924 - accuracy: 0.8417 - val_loss: 0.3936 - val_accuracy: 0.8491
# Epoch 34/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3876 - accuracy: 0.8444 - val_loss: 0.3921 - val_accuracy: 0.8432
# Epoch 35/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3867 - accuracy: 0.8442 - val_loss: 0.3926 - val_accuracy: 0.8395
# Epoch 36/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3837 - accuracy: 0.8461 - val_loss: 0.3899 - val_accuracy: 0.8490
# Epoch 37/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3825 - accuracy: 0.8471 - val_loss: 0.3900 - val_accuracy: 0.8491
# Epoch 38/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3839 - accuracy: 0.8477 - val_loss: 0.3871 - val_accuracy: 0.8510
# Epoch 39/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3805 - accuracy: 0.8487 - val_loss: 0.3858 - val_accuracy: 0.8483
# Epoch 40/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3793 - accuracy: 0.8500 - val_loss: 0.3850 - val_accuracy: 0.8471
# Epoch 41/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3762 - accuracy: 0.8517 - val_loss: 0.3843 - val_accuracy: 0.8466
# Epoch 42/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3770 - accuracy: 0.8513 - val_loss: 0.3833 - val_accuracy: 0.8508
# Epoch 43/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3749 - accuracy: 0.8516 - val_loss: 0.3817 - val_accuracy: 0.8489
# Epoch 44/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3728 - accuracy: 0.8530 - val_loss: 0.3798 - val_accuracy: 0.8534
# Epoch 45/45
# 677/677 [==============================] - 15s 22ms/step - loss: 0.3718 - accuracy: 0.8535 - val_loss: 0.3789 - val_accuracy: 0.8500

# %%
model.evaluate(X_test_res,y_test_res)
# Out:
# 5269/5269 [==============================] - 11s 2ms/step - loss: 2.0570 - accuracy: 0.4940
# [2.0570223331451416, 0.4939919710159302]

# %%
model_history.history
# Out:
# {'accuracy': [0.5200121402740479,
#   0.6450742483139038,
#   0.6748321652412415,
#   0.7017720937728882,
#   0.7279231548309326,
#   0.7564781308174133,
#   0.7917261719703674,
#   0.8118467926979065,
#   0.8188849091529846,
#   0.8232707381248474,
#   0.8256253600120544,
#   0.8258481621742249,
#   0.8275184631347656,
#   0.8285794258117676,
#   0.8290448188781738,
#   0.8298908472061157,
#   0.8308787941932678,
#   0.8314841985702515,
#   0.8324840664863586,
#   0.8333359360694885,
#   0.8340123891830444,
#   0.8346848487854004,
#   0.8353415131568909,
#   0.8359587788581848,
#   0.8365582823753357,
#   0.8370493054389954,
#   0.8378933072090149,
#   0.8385539650917053,
#   0.8393684029579163,
#   0.8401039838790894,
#   0.8410308361053467,
#   0.8416401743888855,
#   0.8427858948707581,
#   0.8438311219215393,
#   0.8450281023979187,
#   0.845767617225647,
#   0.8472466468811035,
#   0.8481005430221558,
#   0.8489307761192322,
#   0.8499128222465515,
#   0.8507667183876038,
#   0.8516738414764404,
#   0.8519578576087952,
#   0.8527880311012268,
#   0.8533934950828552],
#  'loss': [1.5189744234085083,
#   0.9698653221130371,
#   0.851068377494812,
#   0.777481734752655,
#   0.7186079025268555,
#   0.6640269160270691,
#   0.6115798950195312,
#   0.565178632736206,
#   0.5283207893371582,
#   0.5010503530502319,
#   0.4808584749698639,
#   0.46526679396629333,
#   0.45337045192718506,
#   0.4441949129104614,
#   0.43681466579437256,
#   0.43073132634162903,
#   0.4256402254104614,
#   0.42143234610557556,
#   0.41779381036758423,
#   0.4145994782447815,
#   0.4116363227367401,
#   0.409065306186676,
#   0.4067506492137909,
#   0.40463986992836,
#   0.4026261270046234,
#   0.4007115364074707,
#   0.398865669965744,
#   0.3971301317214966,
#   0.39549902081489563,
#   0.3938630223274231,
#   0.3922666013240814,
#   0.39068204164505005,
#   0.38912150263786316,
#   0.38758113980293274,
#   0.38609686493873596,
#   0.3846447467803955,
#   0.3832218050956726,
#   0.3817985951900482,
#   0.3804161548614502,
#   0.3790135979652405,
#   0.37758347392082214,
#   0.37619748711586,
#   0.37489190697669983,
#   0.3735939860343933,
#   0.37232375144958496],
#  'val_accuracy': [0.6103802919387817,
#   0.6681533455848694,
#   0.6947535276412964,
#   0.71875,
#   0.7495670318603516,
#   0.7686704993247986,
#   0.8020022511482239,
#   0.8200796842575073,
#   0.8224105834960938,
#   0.8247058391571045,
#   0.8293497562408447,
#   0.8307079076766968,
#   0.8307197690010071,
#   0.8318525552749634,
#   0.830755352973938,
#   0.8357551097869873,
#   0.8338038325309753,
#   0.8351560831069946,
#   0.8370065689086914,
#   0.8380147814750671,
#   0.8334242701530457,
#   0.8372496962547302,
#   0.8389874696731567,
#   0.841223418712616,
#   0.8374276161193848,
#   0.8378665447235107,
#   0.845885157585144,
#   0.8459622263908386,
#   0.8381986618041992,
#   0.8448887467384338,
#   0.8466205596923828,
#   0.8468103408813477,
#   0.8490700125694275,
#   0.8431628346443176,
#   0.839491605758667,
#   0.8489869832992554,
#   0.8491174578666687,
#   0.8509975671768188,
#   0.8482693433761597,
#   0.8470950126647949,
#   0.8465849757194519,
#   0.8507840633392334,
#   0.8489158153533936,
#   0.8534114360809326,
#   0.8499655723571777],
#  'val_loss': [1.069602608680725,
#   0.904053807258606,
#   0.8188086152076721,
#   0.7504648566246033,
#   0.6939373016357422,
#   0.6374765038490295,
#   0.5857313275337219,
#   0.5422232151031494,
#   0.510032594203949,
#   0.48602938652038574,
#   0.4687044620513916,
#   0.45542240142822266,
#   0.4464089274406433,
#   0.4393015503883362,
#   0.4327619969844818,
#   0.4282698631286621,
#   0.42488929629325867,
#   0.42057204246520996,
#   0.4177475869655609,
#   0.41517728567123413,
#   0.4141477644443512,
#   0.4108583629131317,
#   0.40868303179740906,
#   0.40723130106925964,
#   0.4057811200618744,
#   0.40448957681655884,
#   0.4032650291919708,
#   0.40238717198371887,
#   0.3995544910430908,
#   0.3975491225719452,
#   0.3959128260612488,
#   0.3979160487651825,
#   0.3935582935810089,
#   0.39210882782936096,
#   0.39260178804397583,
#   0.3899066746234894,
#   0.38999029994010925,
#   0.38710901141166687,
#   0.38579946756362915,
#   0.3849910497665405,
#   0.38432079553604126,
#   0.38330623507499695,
#   0.38167569041252136,
#   0.3797796964645386,
#   0.3788796663284302]}

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
pd.DataFrame(model_history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()
